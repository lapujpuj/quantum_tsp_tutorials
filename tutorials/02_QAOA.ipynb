# %% [markdown]
# # QAOA - Quantum Approximate Optimization Algorithm

# %% [markdown]
# In this notebook I would like to show you one of the most prominent algorithms in the quantum computing in the last few years.

# %% [markdown]
# In this tutorial you will learn the following:
# - How to use pyQuil - python platform for quantum computing.
# - How to solve MaxCut problem using QAOA implementation in pyQuil.
# - What does it mean in practice that quantum computing is probabilistic.
# - Basic information about how QAOA works.

# %% [markdown]
# This is probably the most theoretical notebook in this series, especially the second part. If you get discouraged by this and don't get everything, don't worry. Take your time, try reading different resources or just go to the next part and come back later. These ideas are that difficult, but are pretty complicated at times and they may just need some time to sink in :)

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# Before we can go into QAOA itself, you should prepare a couple of things:
# 1. Download and install [Forest SDK](https://qcs.rigetti.com/sdk-downloads)
# 2. Install [pyQuil](https://github.com/rigetticomputing/pyquil) and [Grove](https://github.com/rigetticomputing/grove)
# 3. Learn the basics of quantum computing by yourself - there are plenty of great resources about the basics in the web and I decided I don't want to reinvent the wheel in this tutorial. I recommend going to [pyQuil documentation](http://pyquil.readthedocs.io/en/stable/).
# 4. You can also check out [this tutorial](https://github.com/markf94/rigetti_training_material) by guys from [ProteinQure](https://proteinqure.com). It was designed for the workshops, not self-learning, but there are many hands-on exercises and it will be a good test of your pyQuil skills :)
#
# Even though I tried to make this tutorial as accessible to the not-quantum-computing people as possible, you probably need some level of familiarity with the following concepts:
# - qubits
# - quantum gates
# - superposition
# - entanglement
#
# You don't need to go very in-depth - I think spending about 30 minutes with the pyQuil docs should be enough for the beginning. And if something is still confusing later on you can always come back to the documentation when you need it :)

# %% [markdown]
# ### Terminology

# %% [markdown]
# We need this line to have a proper [bra-ket](https://en.wikipedia.org/wiki/Bra–ket_notation) formatting in markdown.
# $$
# \newcommand{\ket}[1]{\left| #1 \right\rangle}
# \newcommand{\bra}[1]{\left\langle #1 \right|}
# $$

# %% [markdown]
# I try to use as easy language as possible and by easy I mean not very specific neither for physicists, programmers nor quantum computing people. But sometimes it's just not possible, so here I will try to explain you some important concepts in layman terms. These explanation won't give you deep understanding, rather a general overview.

# %% [markdown]
# `Operator` - well... if you are not very mathematically accurate, you can treat "operator" as a fancy name for a matrix. If you are - I'm not the best person to explain it to you ;) But in essence, operators represents some kind of action on a quantum state and there is a matrix associated with every operator, so these terms are sometimes used interchangeably.

# %% [markdown]
# `Hamiltonian` is an operator describing the quantum system. It's eigenvalues represent the energy values that the system can have.

# %% [markdown]
# `Pauli matrix` is one of the three 2x2 matrices commonly used in quantum computing. They have very interesting properties ([wiki](https://en.wikipedia.org/wiki/Pauli_matrices)) and they correspond to some very basic operations on qubits. You will see a lot of them while doing quantum computing.
#
# - $\sigma_x$ -> X gate. It flips $\ket 0$ and $\ket 1$, so it's equivalent to logical NOT gate.
# - $\sigma_y$ -> Y gate. It maps $\ket 0$ into $i \ket 1$ and $\ket 1$ into $-i \ket 0$
# - $\sigma_z$ -> Z gate. It doesn't affect $\ket 0$ state, but changes $\ket 1$ -> - $\ket 1$

# %% [markdown]
# ## QAOA - intro

# %% [markdown]
# QAOA is an algorithm for solving a broad range of optimization problems using NISQ (Noisy Intermediate-Scale Quantum) devices.
#
# Let's start easy and instead of going straight to the TSP we will solve MaxCut problem. This part is based on the [Rigetti's tutorial on QAOA](https://grove-docs.readthedocs.io/en/latest/qaoa.html).

# %% [markdown]
# ### MaxCut - explanation

# %% [markdown]
# In the MaxCut problem we start with a graph and we want to divide it into two subgraphs in such way, that the edges between them would have the highest possible sum.

# %% [markdown]
# Let's take look on an example. We will color the nodes with blue and red to distinguish into which group they fall - let's say blue represents 0 and red represents 1.
#
# We start easy with a graph with two nodes and one connection:
# ![](images/02_2_nodes.png)

# %% [markdown]
# We can color it in the following ways:
# ![](images/02_2_nodes_cuts.png)

# %% [markdown]
# Now, a little more advanced example:
# ![](images/02_3_nodes_cuts.png)

# %% [markdown]
# To understand it better I recommend drawing a 4-node graph on a paper and try to solve it by hand.
#
# If you still don't get it, check out [this section of the Rigetti's tutorial](https://grove-docs.readthedocs.io/en/latest/qaoa.html#our-first-np-hard-problem).

# %% [markdown]
# ### QAOA solves MaxCut - quick take

# %% [markdown]
# Let's take a graph with four nodes.
# We encode it as a list of tuples, where each tuple represents an edge between given nodes.

# %%
first_graph = [(0, 1), (0, 2), (0, 3)]

# %% [markdown]
# ![](images/02_4_nodes.png)
# The optimal solution for this graph is either 1000 or 0111:

# %% [markdown]
# Now let's try to solve MaxCut problem for this graph using maxcut_solver from the grove library.
#
# Keep in mind that runtime of this algorithm are non-deterministic - it should finish running under a minute, but sometimes it takes longer.

# %%
import numpy as np
from grove.pyqaoa.maxcut_qaoa import maxcut_qaoa
import pyquil.api as api
# qvm_connection = api.QVMConnection()
from pyquil import Program, get_qc
from pyquil.gates import *
from pyquil.quilbase import Declare
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 2
#       1 import numpy as np
# ----> 2 from grove.pyqaoa.maxcut_qaoa import maxcut_qaoa
#       3 import pyquil.api as api
#       4 # qvm_connection = api.QVMConnection()
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyqaoa\maxcut_qaoa.py:26
#      24 from scipy.optimize import minimize
#      25 from grove.pyqaoa.qaoa import QAOA
# ---> 26 CXN = api.QVMConnection()
#      29 def print_fun(x):
#      30     print(x)
#
# AttributeError: module 'pyquil.api' has no attribute 'QVMConnection'

# %% [markdown]
# First let's make a simple Bell State program

# %%
# !qvm -S

# %%
# !quilc -S

# %%
p = Program(
    Declare("ro", "BIT", 2),
    H(0),
    CNOT(0, 1),
    MEASURE(0, ("ro", 0)),
    MEASURE(1, ("ro", 1)),
).wrap_in_numshots_loop(10)

# %%
# run the program on a QVM
qc = get_qc('9q-square-qvm')
result = qc.run(qc.compile(p)).get_register_map().get("ro")
print(result[0])
print(result[1])
print(np.mean(result, axis = 0))
# Out:
# [1 1]
# [1 1]
# [0.6 0.6]

# %% [markdown]
# ## QAOA - how does it work?

# %% [markdown]
# ### Black box approach

# %% [markdown]
# The easiest way to look at QAOA is to think only about its inputs and outputs.
# <br>
# To solve the MaxCut problem the only thing we needed was the graph, which we passed to the instance of `maxcut_qaoa` class. But if you look into [its body](https://github.com/rigetticomputing/grove/blob/master/grove/pyqaoa/maxcut_qaoa.py), you will see that inside we use `qaoa` class with a little bit more advanced version of the following line:
#
# ```
# QAOA_inst = QAOA(connection, qubits, steps=steps, cost_ham=cost_operators,
#                      ref_ham=driver_operators,
#                      init_betas=initial_beta,
#                      init_gammas=initial_gamma,
#                      minimizer_kwargs=minimizer_kwargs)
# ```

# %% [markdown]
# `connection` is just a regular `api.QVMConnection()` - so we tell QAOA how it should talk to the Forest cloud.

# %% [markdown]
# `qubits` are the same qubits that we used earlier.

# %% [markdown]
# `steps` is an integer, which specifies how long our quantum program will be. By default it's equal to 1 and that's the value we used in our MaxCut example. We will return to this later.

# %% [markdown]
# `cost_ham` (`cost_operators`) is how we encode our problem. This is where all the information about our graph sits and it's encoded as a combination of Pauli operators.

# %% [markdown]
# `ref_ham` (`driver_operators`) is how we encode what changes are possible in the realm of our problem. In `maxcut_qaoa` we say that we can flip every qubit from 0 to 1. Again - we use only Pauli operators to create it.

# %% [markdown]
# `init_gammas` and `init_betas` are just the initial values for the $\gamma$ and $\beta$ angles.

# %% [markdown]
# `minimizer_kwargs` is a dictionary with the minimizer arguments. As you can see in an example below, we specify the minimization method and its options.
# ```
# minimizer_kwargs = {'method': 'Nelder-Mead',
#                             'options': {'ftol': 1.0e-2, 'xtol': 1.0e-2,
#                                         'disp': False}}
#
# ```

# %% [markdown]
# You may wonder why it's a `minimizer` since we want to find a maximum cut. This is due to a nice property of optimization problems, that maximization is just a minimization with of the same problem but with a minus in the cost function. Since most optimization algorithms are stated in terms of minimization, we stick to this convention.

# %% [markdown]
# After we have all that we need to run the actual algorithm and find the right angles. Then we create a quantum program which gives us solution to the problem we specified with the `cost_operators`:
# ```
# betas, gammas = QAOA_inst.get_angles()
# QAOA_inst.get_parametrized_program()
# ```
#
# Or actually, we can go straight for the answer with:
# ```
# QAOA_inst.get_string(betas, gammas)
# ```

# %% [markdown]
# This is probably not the simplest black box interface, but honestly, it's not extremely complicated either. The only non-obvious part is what should the cost and driver operators be. Let's see in the next section!

# %% [markdown]
# ### How to encode our problem

# %% [markdown]
# Since in MaxCut we want to create to subsets of nodes, given node is either in set $A$ or $B$.
# <br>
# The total cost of our solution is:
# <br>
# <br>
# $C_{total} = \sum C_{ij} = \sum \frac{1}{2} w_{ij} (1 - z_i z_j) $,
# <br>
# <br>
# where the sum goes through all the pairs of nodes and values $z_i$ are equal to 1 if given node is in the set $A$ and -1 if it's in the $B$. $w_{ij}$ is the weight of given edge, which in our current example is equal to 1.
# <br>
#
# It turns out that we can construct a matrix (Hamiltonian), which correspons to this cost function using only Pauli operators:
# <br>
# <br>
# $H_{cost} = \sum \frac{1}{2} w_{ij} (\mathbb{1} - \sigma^z_i \sigma^z_j$)
# <br>
#
# If you wonder what $\mathbb{1}$ is, it's an identity matrix, which can also be considered as special a Pauli matrix.
#
# How does it look like in the code?

# %%
from pyquil.paulis import PauliTerm, PauliSum
import networkx as nx

maxcut_graph = nx.Graph()
for edge in first_graph:
    maxcut_graph.add_edge(*edge)
graph = maxcut_graph.copy()
        
cost_operators = []
for i, j in graph.edges():
    cost_operators.append(PauliTerm("Z", i, 0.5)*PauliTerm("Z", j) + PauliTerm("I", 0, -0.5))

# %% [markdown]
# The code above is copied from the `maxcut_qaoa` class. Let's see how some of these operators look:

# %%
print(cost_operators[0])
print(cost_operators[1])
# Out:
# (0.5+0j)*Z0*Z1 + (-0.5+0j)*I
# (0.5+0j)*Z0*Z2 + (-0.5+0j)*I

# %% [markdown]
# This is how we encode our `cost_operators`, so now let's go to the `driver_operators`.
# They specify how our state can change. In this basic case, let's say that we allow every qubit to just change from 0 to 1 or otherwise. This means that we need a bunch of X gates (which correspond to $\sigma_x$ Pauli matrices):

# %%
driver_operators = []
for i in graph.nodes():
    driver_operators.append(PauliSum([PauliTerm("X", i, -1.0)]))

# %% [markdown]
# And that's it!
# <br>
# Now let's try to actually run the QAOA by ourselves:

# %%
# run the program on a QVM
qc = get_qc('9q-square-qvm')
result = qc.run(qc.compile(p)).get_register_map().get("ro")

# %%
from pyquil.paulis import PauliTerm, PauliSum
import networkx as nx

maxcut_graph = nx.Graph()
for edge in first_graph:
    maxcut_graph.add_edge(*edge)
graph = maxcut_graph.copy()
        
cost_operators = []
for i, j in graph.edges():
    cost_operators.append(PauliTerm("Z", i, 0.5)*PauliTerm("Z", j) + PauliTerm("I", 0, -0.5))

driver_operators = []
for i in graph.nodes():
    driver_operators.append(PauliSum([PauliTerm("X", i, -1.0)]))

from grove.pyqaoa.qaoa import QAOA
from pyquil.api import get_qc
qubits = get_qc('9q-square-qvm').qubits()
initial_beta = 0
initial_gamma = 0
minimizer_kwargs = {'method': 'Nelder-Mead',
                            'options': {'ftol': 1.0e-2, 'xtol': 1.0e-2,
                                        'disp': False}}

QAOA_inst = QAOA(get_qc('9q-square-qvm'), qubits, steps=1, 
                     cost_ham=cost_operators,
                     ref_ham=driver_operators) 
                    #  init_betas=initial_beta,
                    #  init_gammas=initial_gamma,
                    #  minimizer_kwargs=minimizer_kwargs)

# %%
betas, gammas = QAOA_inst.get_angles()
# Out:
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 betas, gammas = QAOA_inst.get_angles()
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyqaoa\qaoa.py:190, in QAOA.get_angles(self)
#     188 # maximizing the cost function!
#     189 param_prog = self.get_parameterized_program()
# --> 190 result = vqe.vqe_run(param_prog, cost_ham, stacked_params, qvm=self.qvm,
#     191                      **self.vqe_options)
#     192 self.result = result
#     193 betas = result.x[:self.steps]
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyvqe\vqe.py:172, in VQE.vqe_run(self, variational_state_evolve, hamiltonian, initial_params, gate_noise, measurement_noise, jacobian, qvm, disp, samples, return_all)
#     169 if 'jac' in arguments:
#     170     self.minimizer_kwargs['jac'] = jacobian
# --> 172 result = self.minimizer(*args, **self.minimizer_kwargs)
#     174 if hasattr(result, 'status'):
#     175     if result.status != 0:
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minimize.py:698, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     695 callback = _wrap_callback(callback, meth)
#     697 if meth == 'nelder-mead':
# --> 698     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     699                                **options)
#     700 elif meth == 'powell':
#     701     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_optimize.py:899, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     897 try:
#     898     for k in range(N + 1):
# --> 899         fsim[k] = func(sim[k])
#     900 except _MaxFuncCallError:
#     901     pass
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_optimize.py:620, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     618 ncalls[0] += 1
#     619 # A copy of x is sent to the user function (gh13740)
# --> 620 fx = function(np.copy(x), *(wrapper_args + args))
#     621 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     622 # backwards-compatibility, also allow np.array([1.3]),
#     623 # np.array([[1.3]]) etc.
#     624 if not np.isscalar(fx):
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyvqe\vqe.py:145, in VQE.vqe_run.<locals>.objective_function(params)
#     137 """
#     138 closure representing the functional
#     139
#    (...)
#     142 :return: (float) expectation value
#     143 """
#     144 pyquil_prog = variational_state_evolve(params)
# --> 145 mean_value = self.expectation(pyquil_prog, hamiltonian, samples, qvm)
#     146 self._current_expectation = mean_value  # store for printing
#     147 return mean_value
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyvqe\vqe.py:236, in VQE.expectation(pyquil_prog, pauli_sum, samples, qvm)
#     233     operator_progs.append(op_prog)
#     234     operator_coeffs.append(p_term.coefficient)
# --> 236 result_overlaps = qvm.expectation(pyquil_prog,
#     237                                   operator_programs=operator_progs)
#     238 result_overlaps = list(result_overlaps)
#     239 assert len(result_overlaps) == len(operator_progs), """Somehow we
#     240 didn't get the correct number of results back from the QVM"""
#
# AttributeError: 'QuantumComputer' object has no attribute 'expectation'

# %%
pip install qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-1.0.2-cp38-abi3-win_amd64.whl.metadata (12 kB)
# Collecting rustworkx>=0.14.0 (from qiskit)
#   Downloading rustworkx-0.14.2-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (1.25.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (1.11.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (1.12)
# Collecting dill>=0.3 (from qiskit)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (2.8.2)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.2.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied
#    -------------------------- ------------ 71.7/107.5 kB 491.5 kB/s eta 0:00:01
#    --------------------------------- ----- 92.2/107.5 kB 525.1 kB/s eta 0:00:01
#    --------------------------------- ----- 92.2/107.5 kB 525.1 kB/s eta 0:00:01
#    --------------------------------- ----- 92.2/107.5 kB 525.1 kB/s eta 0:00:01
#    --------------------------------- ----- 92.2/107.5 kB 525.1 kB/s eta 0:00:01
#    --------------------------------- ----- 92.2/107.5 kB 525.1 kB/s eta 0:00:01
#    -------------------------------------- 107.5/107.5 kB 230.5 kB/s eta 0:00:00
# Installing collected packages: symengine, rustworkx, pbr, dill, stevedore, qiskit
# Successfully installed dill-0.3.8 pbr-6.0.0 qiskit-1.0.2 rustworkx-0.14.2 stevedore-5.2.0 symengine-0.11.0
#   WARNING: The script pbr.exe is installed in 'c:\Users\Martin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install qiskit_ibm_runtime
# Out:
# Collecting qiskit_ibm_runtimeNote: you may need to restart the kernel to use updated packages.
#
#   Downloading qiskit_ibm_runtime-0.21.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: requests>=2.19 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit_ibm_runtime) (2.31.0)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime)
#   Downloading requests_ntlm-1.2.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit_ibm_runtime) (1.25.1)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit_ibm_runtime) (1.26.18)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit_ibm_runtime) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit_ibm_runtime) (1.6.3)
# Collecting ibm-platform-services>=0.22.6 (from qiskit_ibm_runtime)
#   Downloading ibm-platform-services-0.52.0.tar.gz (316 kB)
#      ---------------------------------------- 0.0/316.3 kB ? eta -:--:--
#      --- --------------------------------- 30.7/316.3 kB 640.0 kB/s eta 0:00:01
#      ---- -------------------------------- 41.0/316.3 kB 653.6 kB/s eta 0:00:01
#      ---------- -------------------------- 92.2/316.3 kB 744.7 kB/s eta 0:00:01
#      ----------------- ------------------ 153.6/316.3 kB 913.1 kB/s eta 0:00:01
#      ----------------- ------------------ 153.6/316.3 kB 913.1 kB/s eta 0:00:01
#      ------------------------- ---------- 225.3/316.3 kB 808.4 kB/s eta 0:00:01
#      -------------------------- --------- 235.5/316.3 kB 719.7 kB/s eta 0:00:01
#      ---------------------------------- - 307.2/316.3 kB 863.3 kB/s eta 0:00:01
#      ------------------------------------ 316.3/316.3 kB 752.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pydantic in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit_ibm_runtime) (1.10.14)
# Requirement already satisfied: qiskit>=1.0.0 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit_ibm_runtime) (1.0.2)
# Collecting ibm-cloud-sdk-core<4.0.0,>=3.19.2 (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Downloading ibm-cloud-sdk-core-3.19.2.tar.gz (61 kB)
#      ---------------------------------------- 0.0/62.0 kB ? eta -:--:--
#      ---------------------------------------- 62.0/62.0 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six>=1.5 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.14.2)
# Requirement already satisfied: scipy>=1.5 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (1.11.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (1.12)
# Requirement already satisfied: dill>=0.3 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (4.8.0)
# Requirement already satisfied: symengine>=0.11 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (2023.7.22)
# Requirement already satisfied: cryptography>=1.3 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (42.0.2)
# Collecting pyspnego>=0.1.6 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading pyspnego-0.10.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (1.15.1)
# Collecting urllib3>=1.21.1 (from qiskit_ibm_runtime)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (2.8.0)
# Collecting sspilib>=0.1.0 (from pyspnego>=0.1.6->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading sspilib-0.1.0-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.0.0->qiskit_ibm_runtime) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.3->qiskit>=1.0.0->qiskit_ibm_runtime) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\martin\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.21)
# Downloading qiskit_ibm_runtime-0.21.1-py3-none-any.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.0 MB 2.0 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/3.0 MB 1.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.3/3.0 MB 2.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/3.0 MB 1.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.4/3.0 MB 1.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.4/3.0 MB 1.7 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/3.0 MB 1.5 MB/s eta 0:00:02
#    ------- -------------------------------- 0.5/3.0 MB 1.5 MB/s eta 0:00:02
#    ------- -------------------------------- 0.6/3.0 MB 1.4 MB/s eta 0:00:02
#    -------- ------------------------------- 0.6/3.0 MB 1.3 MB/s eta 0:00:02
#    -------- ------------------------------- 0.7/3.0 MB 1.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.8/3.0 MB 1.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.8/3.0 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 0
#    -------------------------------------- 563.8/563.8 kB 738.1 kB/s eta 0:00:00
# Building wheels for collected packages: ibm-platform-services, ibm-cloud-sdk-core
#   Building wheel for ibm-platform-services (pyproject.toml): started
#   Building wheel for ibm-platform-services (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-platform-services: filename=ibm_platform_services-0.52.0-py3-none-any.whl size=331929 sha256=856aaceaad397e408cd8c9a8cf1f59894e13f5d0d4b2e85981d1c1927983b1df
#   Stored in directory: c:\users\martin\appdata\local\pip\cache\wheels\95\89\8b\5ddc27b85ab3162575cc6fa7a5e8d3229757274a7785cecbae
#   Building wheel for ibm-cloud-sdk-core (pyproject.toml): started
#   Building wheel for ibm-cloud-sdk-core (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.19.2-py3-none-any.whl size=98848 sha256=852ce6573a49c1d1a22648beca2759da243014df85f616594b454898c58b010c
#   Stored in directory: c:\users\martin\appdata\local\pip\cache\wheels\82\4e\e7\3397398b197db5a5027eb72637f96f45b6a942ed1b985e8d32
# Successfully built ibm-platform-services ibm-cloud-sdk-core
# Installing collected packages: urllib3, sspilib, pyspnego, ibm-cloud-sdk-core, requests-ntlm, ibm-platform-services, qiskit_ibm_runtime
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.18
#     Uninstalling urllib3-1.26.18:
#       Successfully uninstalled urllib3-1.26.18
# Successfully installed ibm-cloud-sdk-core-3.19.2 ibm-platform-services-0.52.0 pyspnego-0.10.2 qiskit_ibm_runtime-0.21.1 requests-ntlm-1.2.0 sspilib-0.1.0 urllib3-2.2.1
#   WARNING: The script pyspnego-parse.exe is installed in 'c:\Users\Martin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# botocore 1.34.59 requires urllib3<2.1,>=1.25.4; python_version >= "3.10", but you have urllib3 2.2.1 which is incompatible.
# grove 1.2.2 requires urllib3<2.0, but you have urllib3 2.2.1 which is incompatible.

# %%
# General imports
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# Pre-defined ansatz circuit, operator class and visualization tools
from qiskit.circuit.library import QAOAAnsatz
from qiskit.quantum_info import SparsePauliOp
from qiskit.visualization import plot_distribution

# Qiskit Runtime
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import Estimator, Sampler, Session, Options

# SciPy minimizer routine
from scipy.optimize import minimize

# rustworkx graph library
import rustworkx as rx
from rustworkx.visualization import mpl_draw


import networkx as nx

# Graph creation (unchanged)
maxcut_graph = nx.Graph()
for edge in first_graph:
    maxcut_graph.add_edge(*edge)
graph = maxcut_graph.copy()

# Cost Hamiltonian (using Qiskit Opflow)
cost_operators = []
for i, j in graph.edges():
    cost_term = 0.5 * Z ^ Z(i) ^ Z(j) - 0.5 * I ^ I
    cost_operators.append(cost_term)
cost_hamiltonian = SummedOp(cost_operators)

# Driver Hamiltonian (using Qiskit Opflow)
driver_operators = []
for i in graph.nodes():
    driver_term = -1.0 * X ^ X(i)
    driver_operators.append(driver_term)
driver_hamiltonian = SummedOp(driver_operators)

# QAOA circuit construction
num_qubits = len(graph.nodes())
qc = QuantumCircuit(num_qubits)

# Leverage TwoLocal to create QAOA layers
qaoa_inst = TwoLocal(num_qubits, reps=1, entanglement="full")
qc = qaoa_inst.compose(qc, front=True)

# Define parameter binding for optimization
params = qaoa_inst.parameters  # Get parameters from TwoLocal

# Backend for simulation
backend = Aer.get_backend('aer_simulator')

# Minimize energy expectation value (using SciPy)
from scipy.optimize import minimize

def objective_function(parameters):
    qaoa_inst.assign_parameters(parameters)
    # Compile for noise-free simulation
    compiled_circuit = transpile(qc, backend)
    job = execute(compiled_circuit, backend)
    result = job.result()
    expectation_value = result.expectation_value
    return expectation_value

# Optimization with Nelder-Mead
result = minimize(objective_function, params, method='Nelder-Mead')
optimal_params = result.x
qaoa_inst.assign_parameters(optimal_params)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 from qiskit import QuantumCircuit, Aer, execute
#       2 from qiskit.circuit.library import TwoLocal
#       3 from qiskit.opflow import (
#       4     Z, I, X, PauliSumOp, SummedOp
#       5 )
#
# ImportError: cannot import name 'Aer' from 'qiskit' (c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\__init__.py)

# %%
betas, gammas = QAOA_inst.get_parameterized_program
print("Values of betas:", betas)
print("Values of gammas:", gammas)
print("And the most common measurement is... ")
most_common_result, _ = QAOA_inst.get_string(betas, gammas)
print(most_common_result)
# Out:
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyvqe\vqe.py:172: OptimizeWarning: Unknown solver options: ftol, xtol
#   result = self.minimizer(*args, **self.minimizer_kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 betas, gammas = QAOA_inst.get_angles()
#       2 print("Values of betas:", betas)
#       3 print("Values of gammas:", gammas)
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyqaoa\qaoa.py:190, in QAOA.get_angles(self)
#     188 # maximizing the cost function!
#     189 param_prog = self.get_parameterized_program()
# --> 190 result = vqe.vqe_run(param_prog, cost_ham, stacked_params, qvm=self.qvm,
#     191                      **self.vqe_options)
#     192 self.result = result
#     193 betas = result.x[:self.steps]
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyvqe\vqe.py:172, in VQE.vqe_run(self, variational_state_evolve, hamiltonian, initial_params, gate_noise, measurement_noise, jacobian, qvm, disp, samples, return_all)
#     169 if 'jac' in arguments:
#     170     self.minimizer_kwargs['jac'] = jacobian
# --> 172 result = self.minimizer(*args, **self.minimizer_kwargs)
#     174 if hasattr(result, 'status'):
#     175     if result.status != 0:
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minimize.py:698, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     695 callback = _wrap_callback(callback, meth)
#     697 if meth == 'nelder-mead':
# --> 698     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     699                                **options)
#     700 elif meth == 'powell':
#     701     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_optimize.py:899, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     897 try:
#     898     for k in range(N + 1):
# --> 899         fsim[k] = func(sim[k])
#     900 except _MaxFuncCallError:
#     901     pass
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_optimize.py:620, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     618 ncalls[0] += 1
#     619 # A copy of x is sent to the user function (gh13740)
# --> 620 fx = function(np.copy(x), *(wrapper_args + args))
#     621 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     622 # backwards-compatibility, also allow np.array([1.3]),
#     623 # np.array([[1.3]]) etc.
#     624 if not np.isscalar(fx):
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyvqe\vqe.py:145, in VQE.vqe_run.<locals>.objective_function(params)
#     137 """
#     138 closure representing the functional
#     139
#    (...)
#     142 :return: (float) expectation value
#     143 """
#     144 pyquil_prog = variational_state_evolve(params)
# --> 145 mean_value = self.expectation(pyquil_prog, hamiltonian, samples, qvm)
#     146 self._current_expectation = mean_value  # store for printing
#     147 return mean_value
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\grove\pyvqe\vqe.py:236, in VQE.expectation(pyquil_prog, pauli_sum, samples, qvm)
#     233     operator_progs.append(op_prog)
#     234     operator_coeffs.append(p_term.coefficient)
# --> 236 result_overlaps = qvm.expectation(pyquil_prog,
#     237                                   operator_programs=operator_progs)
#     238 result_overlaps = list(result_overlaps)
#     239 assert len(result_overlaps) == len(operator_progs), """Somehow we
#     240 didn't get the correct number of results back from the QVM"""
#
# AttributeError: 'QuantumComputer' object has no attribute 'expectation'

# %%
# General imports
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# Pre-defined ansatz circuit, operator class and visualization tools
from qiskit.circuit.library import QAOAAnsatz
from qiskit.quantum_info import SparsePauliOp
from qiskit.visualization import plot_distribution

# Qiskit Runtime
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import Estimator, Sampler, Session, Options

# SciPy minimizer routine
from scipy.optimize import minimize

# rustworkx graph library
import rustworkx as rx
from rustworkx.visualization import mpl_draw
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[118], line 12
#       9 from qiskit.visualization import plot_distribution
#      11 # Qiskit Runtime
# ---> 12 from qiskit_ibm_runtime import QiskitRuntimeService
#      13 from qiskit_ibm_runtime import Estimator, Sampler, Session, Options
#      15 # SciPy minimizer routine
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit_ibm_runtime\__init__.py:176
#     173 from .utils.utils import setup_logger
#     174 from .version import __version__
# --> 176 from .estimator import (  # pylint: disable=reimported
#     177     EstimatorV2,
#     178     EstimatorV1,
#     179     EstimatorV1 as Estimator,
#     180 )
#     181 from .sampler import (  # pylint: disable=reimported
#     182     SamplerV2,
#     183     SamplerV1,
#     184     SamplerV1 as Sampler,
#     185 )
#     186 from .options import Options, EstimatorOptions, SamplerOptions
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit_ibm_runtime\estimator.py:30
#      28 from .runtime_job_v2 import RuntimeJobV2
#      29 from .ibm_backend import IBMBackend
# ---> 30 from .options import Options
#      31 from .options.estimator_options import EstimatorOptions
#      32 from .base_primitive import BasePrimitiveV1, BasePrimitiveV2
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit_ibm_runtime\options\__init__.py:98
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2022, 2024
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 =====================================================
#      15 Primitive options (:mod:`qiskit_ibm_runtime.options`)
#    (...)
#      95
#      96 """
# ---> 98 from .environment_options import EnvironmentOptions
#      99 from .execution_options import ExecutionOptions
#     100 from .execution_options import ExecutionOptionsV2
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit_ibm_runtime\options\environment_options.py:17
#      13 """Options related to the execution environment."""
#      15 from typing import Optional, Callable, List, Literal
# ---> 17 from .utils import primitive_dataclass
#      19 LogLevelType = Literal[
#      20     "DEBUG",
#      21     "INFO",
#    (...)
#      24     "CRITICAL",
#      25 ]
#      28 @primitive_dataclass
#      29 class EnvironmentOptions:
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit_ibm_runtime\options\utils.py:23
#      20 from dataclasses import is_dataclass, asdict
#      21 from numbers import Real
# ---> 23 from pydantic import ConfigDict, ValidationInfo, field_validator
#      24 from pydantic.dataclasses import dataclass
#      26 from ..ibm_backend import IBMBackend
#
# ImportError: cannot import name 'ValidationInfo' from 'pydantic' (c:\Users\Martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\__init__.cp311-win_amd64.pyd)

# %%
import numpy as np
from pyquil import Program
from pyquil.api import QuantumComputer, WavefunctionSimulator
from pyquil.gates import H, MEASURE
from pyquil.paulis import exponential_map, PauliSum
from scipy import optimize, ufunc

from grove.pyvqe.vqe import VQE

# %%
pip install upgrade grove
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement upgrade (from versions: none)
# ERROR: No matching distribution found for upgrade

# %% [markdown]
# Awesome! Now you have all the tools to use QAOA, except the most important one...

# %% [markdown]
# Knowing how it actually works ;)

# %% [markdown]
# ### What are betas and gammas?

# %% [markdown]
# Imagine you're in the mountains and you want to find the lowest valley. In this analogy if we used the classical gradient descent method, you will start from some point and climb downwards until we can't find anything better. Most of the classical algorithms work this way - you are a moving around the mountain range to find this valley.
# <br>
# Here it's a little bit different. You start with some simple landscape and standing in the lowest point. Then, very, very slowly, the mountains start erecting from the ground. If this means that the minimum shifts, you do a little step. In the end, the mountains are the same as they were in the previous example and you are standing in the lowest valley.
# <br>
# What's happening here is the adiabatic transformation from some initial hamiltonian to the hamiltonian representing our problem. It is proven that if it's done slowly enough, the ground state (state of the minimal energy) of the initial hamiltonian will transform smoothly into the ground state of the final hamiltonian. It is also how the quantum annealers work (e.g. D-Wave).
# <br>
# One of the problems is that using Rigetti's quantum computer (or any other gate based machine) we cannot do this transformation in infinite number of infinitely small steps. We need to set how many steps we want and this is what `steps` parameter does. The more steps we have, the higher chance we will get the good result, but we also need more gates and running the algorithm gets longer and longer. Also, it means we have more betas and gammas to optimize. In this metaphore, betas and gammas tell you how exactly should you add new mountains in each step.

# %% [markdown]
# For those of you, who prefer equations over methaphores - below is the short version of how it works. We start with some definitions and then go to the explanations:

# %% [markdown]
# ${\displaystyle U(C,\gamma) = e^{-i \gamma C} = \prod_{\alpha} e^{-i \gamma C_{\alpha}} }$, where $C_{\alpha}$ are the cost operators we defined earlier.
# <br>
# ${\displaystyle U(B,\beta) = e^{-i \beta B} = \prod_{j} e^{-i \beta B_{j}} }$, where $B_{j}$ are the driver operators we defined earlier.
# <br>
# $\ket{s}$ is the initial state.
# <br>
# And finally: $\ket{\beta, \gamma} = U(B, \beta) U(C, \gamma) \ket{s}$
# <br>

# %% [markdown]
# This is for the case where `steps=2`, but it generalizes nicely to higher number of steps, e.g.:
# <br>
# $\ket{\beta, \gamma} = U(B, \beta_1) U(B, \beta_0) U(C, \gamma_1) U(C, \gamma_0)\ket{s}$

# %% [markdown]
# If you are not familiar with this notation here is a step-by-step description of what does it mean in practice:
# - Let's take some initial state $\ket{s}$
# - Evolve this state using the operator $U(C, \gamma_0)$
# - Evolve this state further using the rest of operators, from right to left.
#
# "Evolving" is just a fancy name for "changing" that we use when talking about the states in quantum computing.

# %% [markdown]
# And now, if the values of angles $\beta$ and $\gamma$ are the right ones, we get a state which is a ground state of the Hamiltonian defining our problem, which should correspond to our solution.
# If you wonder why we call $\gamma$ and $\beta$ angles, that's because $U(C, \gamma)$ and $U(B, \beta)$ correspond to rotations by angles $\gamma$ and $\beta$ in some high dimensional space.

# %% [markdown]
# ### How to find the right angles? The hybrid part

# %% [markdown]
# QAOA is an iterative algorithm, which in every iteration uses a quantum and a classical part.

# %% [markdown]
# **Quantum**
# 1. Prepare a quantum state based on the current values of $\gamma$ and $\beta$.
# 2. Measure the state.
# 3. Repeat many times to get some statistics.
#
# **Classical**
#
# Here we use some classical optimization method, e.g. Nelder-Mead algorithm, and in each iteration of this algorithm we perform the quantum operations to evaluate how good our current angles are.
# <br>
# The algorithm ends when we can't further improve the angles.

# %% [markdown]
# ## Summary and next steps

# %% [markdown]
# What we learned?
#
# - how to solve MaxCut problem using QAOA
# - how to use QAOA class from grove
# - how to encode an optimization problem for QAOA
# - what the QAOA is and how it works
#
# What's next?
#
# - Solving TSP using QAOA

# %% [markdown]
# ## Additional resources

# %% [markdown]
# - [Pauli matrices](https://en.wikipedia.org/wiki/Pauli_matrices)
# - [Original QAOA paper](https://arxiv.org/abs/1411.4028)
# - [QAOA Grove docs](https://grove-docs.readthedocs.io/en/latest/qaoa.html)
# - [Source code of MaxCut QAOA in Grove](https://github.com/rigetticomputing/grove/blob/master/grove/pyqaoa/maxcut_qaoa.py)
# - [Presentation from one of the creators of QAOA](https://youtu.be/J8y0VhnISi8)
